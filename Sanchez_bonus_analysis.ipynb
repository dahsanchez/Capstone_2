# %% [markdown]
# ## Capstone 2 Bonus Analysis

# %% [markdown]
# ### These are bonus analysis qurestion that I was given

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
StoreDetail = pd.read_csv('StoreDetail.csv') # importing data csv

# %%
StoreSales = pd.read_csv('StoreSales.csv') # importing data csv

# %%
Products = pd.read_csv('Products.csv') # importing data csv

# %%
ProductCat = pd.read_csv('ProductCategories.csv') # importing data csv

# %%
CustList = pd.read_csv('customer_list.csv') # importing data csv

# %% [markdown]
# ### Filtering, Sorting & Exploration

# %% [markdown]
# #### Create a list of all transactions from January 2024, sorted by sale amount from highest to lowest. Which transactions had a sale amount greater than $500?

# %%
StoreSales['Transaction Date'] = pd.to_datetime(StoreSales['Transaction Date'])

TransData = StoreSales.groupby(

# %% [markdown]
# #### Find all products whose product number begins with 10525. What category and subcategory do they belong to?

# %%
ProdNumCat = Products.merge(ProductCat, on='CategoryID')
ProdCat = ProdNumCat[['Prod Num','Category','Subcategory']]
ProdNumCat = ProdNumCat[ProdNumCat['Prod Num'] == '10525']
ProdCat
# Out:
#        Prod Num                  Category                   Subcategory
# 0     105248-IT  Technology & Accessories                       Tablets
# 1     105248-IT  Technology & Accessories                   Calculators
# 2     105248-IT  Technology & Accessories             Software Download
# 3     105248-IT  Technology & Accessories                    Headphones
# 4     105248-IT  Technology & Accessories          External Accessories
# ...         ...                       ...                           ...
# 5667   105916-M   Apparel and Merchandise                Home and Decor
# 5668   105916-M   Apparel and Merchandise                 Hats and Caps
# 5669   105916-M   Apparel and Merchandise  Memorabilia and Collectibles
# 5670   105916-M   Apparel and Merchandise       Sports and Outdoor Gear
# 5671   105916-M   Apparel and Merchandise                   Accessories
#
# [5672 rows x 3 columns]

# %% [markdown]
# #### Which stores in your assigned territories had at least one transaction with a sale amount over $1,000? How many such transactions did each store have?
